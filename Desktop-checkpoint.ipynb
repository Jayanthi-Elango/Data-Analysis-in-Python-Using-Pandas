# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }

# %% [markdown]
# # Data Analysis of Kaggle Dataset ofGoogle PlayStore Apps in Python using Pandas . This is an academic Project from Udemy Course

# %% [markdown]
# #### The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market! Each app (row) has values for category, rating, size, Installs type and more.

# %% [markdown]
# https://www.kaggle.com/lava18/google-play-store-apps

# %% [markdown]
# ### Import pandas Library

# %%
import pandas as pd

# %% [markdown]
# ### Read googleplaystore.csv file in DataFrame

# %%
df = pd.read_csv("C:\\Users\\jayanthi\\Downloads\\Pandas+Exercise\\googleplaystore.csv", index_col=0)
df
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# Paper flowers instructions                               ART_AND_DESIGN
# Smoke Effect Photo Maker - Smoke Editor                  ART_AND_DESIGN
# Infinite Painter                                         ART_AND_DESIGN
# Garden Coloring Book                                     ART_AND_DESIGN
# Kids Paint Free - Drawing Fun                            ART_AND_DESIGN
# Text on Photo - Fonteee                                  ART_AND_DESIGN
# Name Art Photo Editor - Focus n Filters                  ART_AND_DESIGN
# ...

# %% [markdown]
# ### Display first few records

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# ### Display name of all the columns and their number of records present in the Google Play Store Data Set

# %%
# .info() provides the essential details about your dataset, such as the number of rows and columns, 
# the number of non-null values, what type of data is in each column, and how much memory your DataFrame is using.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Calculate statistical parameters for the numerical column

# %%
# Another fast and useful attribute is .shape, which outputs just a tuple of (rows, columns):
# Note that .shape has no parentheses and is a simple tuple of format (rows, columns). 
# So we have 10841 rows and 12 columns in our DataFrame.

# %%
df.shape
# Out:
# (10841, 12)

# %%
# Handling duplicates

# %%
temp=df.append(df)
temp
temp.shape
# Out:
# (21682, 12)

# %%
temp.drop_duplicates()
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# Paper flowers instructions                               ART_AND_DESIGN
# Smoke Effect Photo Maker - Smoke Editor                  ART_AND_DESIGN
# Infinite Painter                                         ART_AND_DESIGN
# Garden Coloring Book                                     ART_AND_DESIGN
# Kids Paint Free - Drawing Fun                            ART_AND_DESIGN
# Text on Photo - Fonteee                                  ART_AND_DESIGN
# Name Art Photo Editor - Focus n Filters                  ART_AND_DESIGN
# ...

# %%
temp.shape
# Out:
# (21682, 12)

# %%
temp.drop_duplicates()
temp.shape
# Out:
# (21682, 12)

# %%
temp1=df.append(df)
temp1
temp1.shape
# Out:
# (21682, 12)

# %%
# It's a little verbose to keep assigning DataFrames to some temp variables. 
# For this reason, pandas has the inplace keyword argument on many of its methods.
# Using inplace=True will modify the DataFrame object in place:

# %%
temp1.drop_duplicates(inplace=True)

# %%
temp1.shape
# Out:
# (10349, 12)

# %%
# print the column names of our dataset:

# %%
df.columns
# Out:
# Index(['Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price',
#        'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %% [markdown]
# df.describe()

# %% [markdown]
# ### Do the necessary column datatype conversion needed for optimization and better analysis

# %%
df['Reviews'].apply(lambda x: x.replace('M', '')).astype('float')
# Out:
# 0           159.0
# 1           967.0
# 2         87510.0
# 3        215644.0
# 4           967.0
# 5           167.0
# 6           178.0
# 7         36815.0
# 8         13791.0
# 9           121.0
# 10        13880.0
# 11         8788.0
# 12        44829.0
# 13         4326.0
# 14         1518.0
# 15           55.0
# 16         3632.0
# 17           27.0
# 18       194216.0
# 19       224399.0
# 20          450.0
# 21          654.0
# 22         7699.0
# 23           61.0
# 24          118.0
# 25          192.0
# 26        20260.0
# 27          203.0
# 28          136.0
# 29          223.0
#            ...
# 10811         4.0
# 10812        80.0
# 10813        20.0
# 10814       785.0
# 10815      5775.0
# 10816         2.0
# 10817       885.0
# 10818        96.0
# 10819        52.0
# 10820        22.0
# 10821         6.0
# 10822         0.0
# 10823         1.0
# 10824        67.0
# 10825         7.0
# 10826     88486.0
# 10827       117.0
# 10828       291.0
# 10829       603.0
# ...

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %% [markdown]
# ### Display the number of unique values  in category column

# %%
df['Category'].nunique()
# Out:
# 34

# %% [markdown]
# ### What is average rating of app?

# %%
df['Rating'].mean()
# Out:
# 4.193338315362448

# %% [markdown]
# ### What is the average rating of apps under Photography category

# %%
df[df['Category'] == 'PHOTOGRAPHY']['Rating'].mean()
# Out:
# 4.192113564668767

# %% [markdown]
# ### Display the number of free and paid apps in the PlayStore

# %%
df['Type'].value_counts()
# Out:
# Free    10039
# Paid      800
# 0           1
# Name: Type, dtype: int64

# %% [markdown]
# ### What is average value of Reviews

# %%
df['Reviews'].mean()
# Out:
# 444111.9265750392

# %%
df.Genres
# Out:
# App
# Photo Editor & Candy Camera & Grid & ScrapBook                           Art & Design
# Coloring book moana                                         Art & Design;Pretend Play
# U Launcher Lite – FREE Live Cool Themes, Hide Apps                       Art & Design
# Sketch - Draw & Paint                                                    Art & Design
# Pixel Draw - Number Art Coloring Book                         Art & Design;Creativity
# Paper flowers instructions                                               Art & Design
# Smoke Effect Photo Maker - Smoke Editor                                  Art & Design
# Infinite Painter                                                         Art & Design
# Garden Coloring Book                                                     Art & Design
# Kids Paint Free - Drawing Fun                                 Art & Design;Creativity
# Text on Photo - Fonteee                                                  Art & Design
# ...

# %%
# Out:
# 444111.9265750392

# %% [markdown]
# ### Which app has the Maximum number of Reviews?

# %%
maxi=df['Reviews'].max()
df[df['Reviews'] == maxi] ['App']
# Out:
# 2544    Facebook
# Name: App, dtype: object

# %% [markdown]
# ### select top 5 app with maximum reviews

# %%
top_five = list(df['Reviews'].sort_values(ascending=False).head(5).index)
df.iloc[top_five]
# Out:
#                      App       Category  Rating     Reviews  \
# 2544            Facebook         SOCIAL     4.1  78158306.0
# 3943            Facebook         SOCIAL     4.1  78128208.0
# 336   WhatsApp Messenger  COMMUNICATION     4.4  69119316.0
# 381   WhatsApp Messenger  COMMUNICATION     4.4  69119316.0
# 3904  WhatsApp Messenger  COMMUNICATION     4.4  69109672.0
#
#                     Size        Installs  Type Price Content Rating  \
# 2544  Varies with device  1,000,000,000+  Free     0           Teen
# 3943  Varies with device  1,000,000,000+  Free     0           Teen
# 336   Varies with device  1,000,000,000+  Free     0       Everyone
# 381   Varies with device  1,000,000,000+  Free     0       Everyone
# 3904  Varies with device  1,000,000,000+  Free     0       Everyone
#
#              Genres    Last Updated         Current Ver         Android Ver
# 2544         Social  August 3, 2018  Varies with device  Varies with device
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df['Reviews'].apply(lambda x: x.replace('M', '')).astype('float')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Select top app which has maximum Installs

# %%
df['Installs'] = df['Installs'].apply(lambda x : x.replace('+','').replace(',','')).astype('float')
df.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-8a63822ee445> in <module>
# ----> 1 df['Installs'] = df['Installs'].apply(lambda x : x.replace('+','').replace(',','')).astype('float')
#       2 df.info()
#       3 df['Installs'].max()
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-106-8a63822ee445> in <lambda>(x)
# ----> 1 df['Installs'] = df['Installs'].apply(lambda x : x.replace('+','').replace(',','')).astype('float')
#       2 df.info()
#       3 df['Installs'].max()
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10840 non-null object
# Category          10840 non-null object
# Rating            9366 non-null float64
# Reviews           10840 non-null float64
# Size              10840 non-null object
# Installs          10840 non-null float64
# Type              10839 non-null object
# Price             10840 non-null object
# Content Rating    10840 non-null object
# Genres            10840 non-null object
# Last Updated      10840 non-null object
# Current Ver       10832 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(3), object(10)
# memory usage: 1.2+ MB

# %%
df[df['Installs'] == 'Free']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df.drop(labels = 10472, axis = 0, inplace = True)

# %%
max_install = df['Installs'].max()
max_install
# Out:
# 1000000000.0

# %%
top5installs = list(df['Installs'].sort_values(ascending=False).head(5).index)
top5installs
# Out:
# [10472, 3767, 4048, 4147, 4041]

# %%
df.iloc[top5installs]
# Out:
#                                            App            Category  Rating  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame                 1.9    19.0
# 3767              Flipboard: News For Our Time  NEWS_AND_MAGAZINES     4.4
# 4048                                   Dropbox        PRODUCTIVITY     4.4
# 4147              Gboard - the Google Keyboard               TOOLS     4.2
# 4041                              Temple Run 2                GAME     4.3
#
#        Reviews                Size      Installs  Type     Price  \
# 10472     3.0M              1,000+          Free     0  Everyone
# 3767   1284017  Varies with device  500,000,000+  Free         0
# 4048   1860844                 61M  500,000,000+  Free         0
# 4147   1855262  Varies with device  500,000,000+  Free         0
# 4041   8116142                 62M  500,000,000+  Free         0
#
#       Content Rating             Genres    Last Updated         Current Ver  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.loc[10472]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              1.9
# Rating                                                 19
# Reviews                                              3.0M
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                        NaN
# Genres                                  February 11, 2018
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                           NaN
# Name: 10472, dtype: object

# %%
df.iloc[:,1:5]
# Out:
#                   Category  Rating Reviews                Size
# 0           ART_AND_DESIGN     4.1     159                 19M
# 1           ART_AND_DESIGN     3.9     967                 14M
# 2           ART_AND_DESIGN     4.7   87510                8.7M
# 3           ART_AND_DESIGN     4.5  215644                 25M
# 4           ART_AND_DESIGN     4.3     967                2.8M
# 5           ART_AND_DESIGN     4.4     167                5.6M
# 6           ART_AND_DESIGN     3.8     178                 19M
# 7           ART_AND_DESIGN     4.1   36815                 29M
# 8           ART_AND_DESIGN     4.4   13791                 33M
# 9           ART_AND_DESIGN     4.7     121                3.1M
# 10          ART_AND_DESIGN     4.4   13880                 28M
# 11          ART_AND_DESIGN     4.4    8788                 12M
# 12          ART_AND_DESIGN     4.2   44829                 20M
# 13          ART_AND_DESIGN     4.6    4326                 21M
# ...

# %%
df.iloc[1:5,]
# Out:
#                                                  App        Category  Rating  \
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# ...

# %%
df.iloc[1:5,5:]
# Out:
#       Installs  Type Price Content Rating                     Genres  \
# 1     500,000+  Free     0       Everyone  Art & Design;Pretend Play
# 2   5,000,000+  Free     0       Everyone               Art & Design
# 3  50,000,000+  Free     0           Teen               Art & Design
# 4     100,000+  Free     0       Everyone    Art & Design;Creativity
#
#        Last Updated         Current Ver   Android Ver
# 1  January 15, 2018               2.0.0  4.0.3 and up
# 2    August 1, 2018               1.2.4  4.0.3 and up
# 3      June 8, 2018  Varies with device    4.2 and up
# 4     June 20, 2018                 1.1    4.4 and up

# %%
df.empty
# Out:
# False

# %%
my_dictionary={}

# %%
my_dictionary
# Out:
# {'John': 45, 'Amy': 23, 'Abdul': 78, 'Elango': 43}

# %%
my_dictionary={
    "John": 45,
    "Amy": 23,
    "Abdul": 78,
    "Elango": 43
}

# %%
my_dictionar=dict()

# %%
my_dictionar
# Out:
# {}

# %%
my_dictionar=dict()
mydictionar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-744b1e3d9e76> in <module>
#       1 my_dictionar=dict()
# ----> 2 mydictionar
#
# NameError: name 'mydictionar' is not defined

# %%
listofages=[("a",1),("b",2),("c",3),("d",4)]
my_dictr=dict(listofages)
my_dictr
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
listofTuples = [("Hello" , 7), ("hi" , 10), ("there" , 45),("at" , 23),("this" , 77)]

# %%
listofTuples = [("Hello" , 7), ("hi" , 10), ("there" , 45),("at" , 23),("this" , 77)]
my_dictr=dict(listofTuples)
my_dictr
# Out:
# {'Hello': 7, 'hi': 10, 'there': 45, 'at': 23, 'this': 77}

# %%
listofTuples = [("Hello" , 7), ("hi" , 10), ("there" , 45),("at" , 23),("this" , 77)]
my_dictr=dict(listofTuples)
my_dictr
val=7
if val in m_dictr.values():
    print("key")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-95831dd0e8e6> in <module>
#       3 my_dictr
#       4 val=7
# ----> 5 if val in m_dictr.values():
#       6     print("key")
#       7
#
# NameError: name 'm_dictr' is not defined

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20, 'figure.figsize': (10, 8)})

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20, 'figure.figsize': (10, 8)})

# %%
df.plot(kind='scatter', x='Installs', y='Rating', title='Genres (millions) vs Rating')

# %%
import matplotlib.pyplot as plt
df['Type'].value_counts().plot(kind="bar", color="green")

# %%
df['Type'].value_counts().plot(kind="barh")

# %%
plt.available
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-f3e78014af32> in <module>
# ----> 1 plt.available
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'available'

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
import numpy as np
plt.style.use("bmh")
x=np.linspace(10,-10,1000)
plt.plot(np.sin(x),'-')
plt.plot(np.cos(x),'--')

# %%
# bmh
# This style comes from Bayesian Methods for Hackers [3] book. 
# This particularly suits scientific graphing by showing the precision of the plot.

# %%
plt.subplot(1,2,1)
plt.plot(x,x, color= "blue", linestyle="-.")
plt.subplot(1,2,2)
plt.plot(x,np.sin(x), color="green", linestyle="--")

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.randn(100)
y=np.random.randn(100)
#plt.plot(x,y,'o')
plt.scatter(x,y)

# %%
x=np.random.randn(1000)
plt.hist(x)
# Out:
# (array([  8.,  34.,  91., 188., 231., 212., 133.,  83.,  16.,   4.]),
#  array([-2.82861994, -2.23656131, -1.64450267, -1.05244404, -0.4603854 ,
#          0.13167323,  0.72373187,  1.3157905 ,  1.90784914,  2.49990777,
#          3.09196641]),
#  <a list of 10 Patch objects>)
